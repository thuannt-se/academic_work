# %%
# !kernprof -l test-osm-graph.py
# Out:
# /Users/thuannt.se/miniconda3/envs/ox/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /Users/thuannt.se/miniconda3/envs/ox/lib/python3.11/site-packages/shapely/set_operations.py:340: RuntimeWarning: invalid value encountered in union
#   return lib.union(a, b, **kwargs)
# /Users/thuannt.se/miniconda3/envs/ox/lib/python3.11/site-packages/shapely/set_operations.py:340: RuntimeWarning: invalid value encountered in union
#   return lib.union(a, b, **kwargs)
# Figure(800x800)
# ...

# %%
# !python -m line_profiler test-osm-graph.py.lprof
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.205389 s
# File: /Users/thuannt.se/work/jupyter lab/assignment-dijkstra/naive_dijkstra.py
# Function: naive_dijkstra at line 6
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      6                                           @profile
#      7                                           def naive_dijkstra(graph, root):
#      8         1          0.0      0.0      0.0      n = len(graph)
#      9
#     10                                               # initialize distance list as all infinities
#     11         1         50.0     50.0      0.0      dist = [Inf for _ in range(n)]
#     12                                               # set the distance for the root to be 0
#     13         1          0.0      0.0      0.0      dist[root] = 0
#     14                                               # initialize list of visited nodes
#     15         1         43.0     43.0      0.0      visited = [False for _ in range(n)]
#     16
# ...
