# %%
# import required modules
import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
import random
from Shop import Shop
from Warehouse import Warehouse

# %%
from pyscipopt import Model, quicksum, multidict

# %%
#We will pick district 1 for stores location
place_name = "district 1, Ho Chi Minh City"
place_locations = [10.7757, 106.7004]
# read the graph from OpenStreetMap and convert it to Networkx data

# %% [markdown]
# ## 1. Data generator

# %% [markdown]
# ### This section focus on generating data by utilizing the tags of osmx
# First, we will generate a shop data within given places and clean the data so we can plot it in map and create Shop object later they are later

# %%
def shopGenerator(place_name = "district 1, Ho Chi Minh City", sample = 1000):
    tags = {'shop': ['clothes', 'beverages', 'coffee', 'convenience', 'supermarket', 'shoes',
                    'grocery', 'hobby', 'pharmacy', 'bakery', 'furniture', 'mobile_phone', 'gift', 'greengrocer'],
            'amenity': ['restaurant', 'bar', 'cafe', 'fast_food', 'pub']}
    store_gdf = ox.geometries_from_place(place_name, tags=tags)
    point_list = []
    for node in store_gdf.centroid:
        point_list.append([node.y, node.x])
    random.seed(10)
    sampling = random.sample(point_list, sample)
    return [Shop(point[0],point[1], idx+1, random.randint(10,30)) for idx,point in enumerate(sampling)]

# %% [markdown]
# Similar to shop, let's generate a list of warehouses base on building tags of osmx. This might not make sense but we accept that in the scope of this work

# %%
def warehouseGenerator(placename = "district 1, Ho Chi Minh City", sample = 200, number_of_shop = 1000) :
    buildings = ox.geometries_from_place(place_name, tags={'building':True})

    # Extract the latitude and longitude of random warehouses
    random.seed(20)
    random_warehouses = random.sample([[node.y, node.x] for node in buildings.centroid], sample)
    return [Warehouse(point[0],point[1], idx+1, random.randint(500,3000),1000,\
                      [random.randint(1,15) for _ in range(number_of_shop)]) \
            for idx,point in enumerate(random_warehouses)]

# %% [markdown]
# ## 2. Plot shops, warehouse in map

# %%
def drawInMap(data, name, color, place):
    marker_cluster = MarkerCluster().add_to(place)
    for point in data:
        folium.Marker(location=[point.lat, point.long], popup=name, icon=folium.Icon(color=color, icon_color='white', \
                                                                icon=name, angle=0, prefix='fa')).add_to(marker_cluster)

# %%
shop_data = shopGenerator(sample = 200)
warehouse_data = warehouseGenerator(sample = 20, number_of_shop=200)
# Out:
# /Users/thuannt.se/miniconda3/envs/ox/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /Users/thuannt.se/miniconda3/envs/ox/lib/python3.11/site-packages/shapely/set_operations.py:340: RuntimeWarning: invalid value encountered in union
#   return lib.union(a, b, **kwargs)
# /var/folders/73/f6bjb2fs44n3qjx3xfv_d7ph0000gn/T/ipykernel_14040/4182749584.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   for node in store_gdf.centroid:
# /Users/thuannt.se/miniconda3/envs/ox/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /Users/thuannt.se/miniconda3/envs/ox/lib/python3.11/site-packages/shapely/set_operations.py:340: RuntimeWarning: invalid value encountered in union
#   return lib.union(a, b, **kwargs)
# /Users/thuannt.se/miniconda3/envs/ox/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /Users/thuannt.se/miniconda3/envs/ox/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /Users/thuannt.se/miniconda3/envs/ox/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /Users/thuannt.se/miniconda3/envs/ox/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /var/folders/73/f6bjb2fs44n3qjx3xfv_d7ph0000gn/T/ipykernel_14040/3849141521.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   random_warehouses = random.sample([[node.y, node.x] for node in buildings.centroid], sample)

# %%
place_map = folium.Map(place_locations, tiles='CartoDB positron', zoom_start=13)
drawInMap(shop_data, 'shop', 'green', place_map)
drawInMap(warehouse_data, 'warehouse', 'blue', place_map)
place_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c07014c50b4cec261921ceecd3743b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c07014c50b4cec261921ceecd3743b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c07014c50b4cec261921ceecd3743b2 = L.map(
#                 &quot;map_6c07014c50b4cec261921ceecd3743b2&quot;,
#                 {
#                     center: [10.7757, 106.7004],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_337e90fcb13c8c28c35398b60716c6ba = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c07014c50b4cec261921ceecd3743b2);
#
#
#             var marker_cluster_82b15471ac6a9c359f6eb4c9b91c5bff = L.markerClusterGroup(
#                 {}
#             );
#             map_6c07014c50b4cec261921ceecd3743b2.addLayer(marker_cluster_82b15471ac6a9c359f6eb4c9b91c5bff);
#
#
#             var marker_6bc9d098d97ba293cf60a5b10505a72b = L.marker(
#                 [10.7702895, 106.6927854],
#                 {}
#             ).addTo(marker_cluster_82b15471ac6a9c359f6eb4c9b91c5bff);
#
#
#             var icon_8bbdb68440a919adeeebba1615585fcf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shop&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6bc9d098d97ba293cf60a5b10505a72b.setIcon(icon_8bbdb68440a919adeeebba1615585fcf);
#
#
#         var popup_6f52819adfccf36e218b265a01b88931 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3c52c5700ff2d47757df32d2ff0e89a = $(`&lt;div id=&quot;html_f3c52c5700ff2d47757df32d2ff0e89a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;shop&lt;/div&gt;`)[0];
#                 popup_6f52819adfccf36e218b265a01b88931.setContent(html_f3c52c5700ff2d47757df32d2ff0e89a);
#
#
#
#         marker_6bc9d098d97ba293cf60a5b10505a72b.bindPopup(popup_6f52819adfccf36e218b265a01b88931)
#         ;
#
#
#
#
#             var marker_86bb57f3948cd1b1ff21cda30b63bbb9 = L.marker(
#                 [10.7817145, 106.6982688],
#                 {}
#             ).addTo(marker_cluster_82b15471ac6a9c359f6eb4c9b91c5bff);
#
#
#             var icon_555c82eedd3480f41f97ce737fd043c9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shop&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_86bb57f3948cd1b1ff21cda30b63bbb9.setIcon(icon_555c82eedd3480f41f97ce737fd043c9);
#
#
#         var popup_2c50588b165b9f3e6ab7d9e283489b28 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e71cf483a9ef661312dfdcb9ee023db1 = $(`&lt;div id=&quot;html_e71cf483a9ef661312dfdcb9ee023db1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;shop&lt;/div&gt;`)[0];
#                 popup_2c50588b165b9f3e6ab7d9e283489b28.setContent(html_e71cf483a9ef661312dfdcb9ee023db1);
#
#
#
#         marker_86bb57f3948cd1b1ff21cda30b63bbb9.bindPopup(popup_2c50588b165b9f3e6ab7d9e283489b28)
#         ;
#
#
#
#
#             var marker_9133a4f08c032004f7895e4ada9ab985 = L.marker(
#                 [10.7685768, 106.6948596],
#                 {}
#             ).addTo(marker_cluster_82b15471ac6a9c359f6eb4c9b91c5bff);
#
#
#             var icon_99092692e70bd6f74ae5fdad87ac9a0f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shop&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9133a4f08c032004f7895e4ada9ab985.setIcon(icon_99092692e70bd6f74ae5fdad87ac9a0f);
#
#
#         var popup_9c1520a1b37a8a9f936811215301af15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %% [markdown]
# ## 3. Optimization problem

# %% [markdown]
# There are n warehouses possible and m shops. The programmer wishes to choose (1) which of the n warehouses to open, and (2) which (open) warehouses to use to supply the m shops, in order to satisfy some fixed daily demand (of shops) at minimum cost. It is assumed that there is a (fixed) cost to open a warehouse, denoted by f_{i}. Let c_{ij} denote the cost to ship a package of goods from warehouse i to shop j. Let d_{j} denote the daily demand (in package) of shop j. Moreover, a warehouse has a maximum output. Let u_{i} denote the maximum number of packages which is manageable by warehouse i (i.e., u_{i} denotes the capacity of warehouse i). Note that shipping cost  c_{ij} is computed by the travel distance from warehouse i to shop j (shortest path).

# %% [markdown]
# ### We could fomulate the above problem by following integer optimization problem

# %% [markdown]
# \begin{align*}
# \text{minimize} \quad & \sum_{j=1}^{m} f_j y_j + \sum_{i=1}^{n} \sum_{j=1}^{m} c_{ij} x_{ij} \\
# \text{subject to} \quad & \sum_{j=1}^{m} x_{ij} = d_i \quad \forall i = 1, \ldots, n \\
# & \sum_{i=1}^{n} x_{ij} \leq M_j y_j \quad \forall j = 1, \ldots, m \\
# & 0 \leq x_{ij} \leq d_i y_j \quad \forall i = 1, \ldots, n; \, j = 1, \ldots, m \\
# & y_j \in \{0, 1\} \quad \forall j = 1, \ldots, m \\
# & x_{ij} \geq 0 \quad \forall i = 1, \ldots, n; \, j = 1, \ldots, m \\
# \end{align*}

# %% [markdown]
# The objective of the problem is to minimize the total cost, which consists of the activation costs for the facilities and the transportation costs. The first set of constraints ensures that the demand of each customer is fulfilled. The second set of constraints limits the capacity of each facility 𝑗: if facility 𝑗 is active, its capacity restriction is enforced; if it is inactive, the demand satisfied by 𝑗 is considered zero. The third set of constraints provides additional upper bounds on the variables

# %%
def flp(I,J,d,M,f,c):
    model = Model("flp")
    x,y = {},{}
    for j in J:
        y[j] = model.addVar(vtype="B", name="y(%s)"%j)
        for i in I:
            x[i,j] = model.addVar(vtype="C", name="x(%s,%s)"%(i,j))
    for i in I:
        model.addCons(quicksum(x[i,j] for j in J) == d[i], "Demand(%s)"%i)
    for j in M:
        model.addCons(quicksum(x[i,j] for i in I) <= M[j]*y[j], "Capacity(%s)"%i)
    for (i,j) in x:
        model.addCons(x[i,j] <= d[i]*y[j], "Strong(%s,%s)"%(i,j))
    model.setObjective(
        quicksum(f[j]*y[j] for j in J) +
        quicksum(c[i,j]*x[i,j] for i in I for j in J),
        "minimize")
    model.data = x,y
    return model

# %% [markdown]
# By using generated data above, we can create the data to input to model

# %%
I, d = multidict({shop.id: shop.demand for shop in shop_data})
J, M, f = multidict({warehouse.id: [warehouse.u, warehouse.f] for warehouse in warehouse_data})

# %%
transformed_data = [{(idx+1, warehouse.id):cost for idx, cost in enumerate(warehouse.c)} \
                    for warehouse in warehouse_data]

# %%
c = {k: v for d in transformed_data for k, v in d.items()}

# %%
model = flp(I, J, d, M, f, c)
model.optimize()
EPS = 1.e-6
# Out:
# presolving:
# (round 1, fast)       0 del vars, 0 del conss, 0 add conss, 4000 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
#    (0.0s) running MILP presolver
#    (0.0s) MILP presolver found nothing
# (round 2, exhaustive) 0 del vars, 0 del conss, 0 add conss, 4000 chg bounds, 0 chg sides, 0 chg coeffs, 4000 upgd conss, 0 impls, 0 clqs
#    (0.0s) probing cycle finished: starting next cycle
#    (0.0s) symmetry computation started: requiring (bin +, int -, cont +), (fixed: bin -, int +, cont -)
#    (0.0s) no symmetry present
# presolving (3 rounds: 3 fast, 2 medium, 2 exhaustive):
#  0 deleted vars, 0 deleted constraints, 0 added constraints, 4000 tightened bounds, 0 added holes, 0 changed sides, 0 changed coefficients
#  4000 implications, 0 cliques
# presolved problem has 4020 variables (20 bin, 0 int, 0 impl, 4000 cont) and 4220 constraints
#    4000 constraints of type <varbound>
#     220 constraints of type <linear>
# Presolving Time: 0.04
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# p 0.1s|     1 |     0 |   200 |     - |   locks|   0 |4020 |4220 |4220 |   0 |  0 |   0 |   0 | 0.000000e+00 | 2.518300e+04 |    Inf | unknown
#   0.6s|     1 |     0 |  7979 |     - |    42M |   0 |4020 |4220 |4220 |   0 |  0 |   0 |   0 | 1.389826e+04 | 2.518300e+04 |  81.20%| unknown
#   0.6s|     1 |     0 |  8044 |     - |    44M |   0 |4020 |4220 |4221 |   1 |  1 |   0 |   0 | 1.390496e+04 | 2.518300e+04 |  81.11%| unknown
#   0.6s|     1 |     0 |  8095 |     - |    44M |   0 |4020 |4220 |4222 |   2 |  2 |   0 |   0 | 1.391229e+04 | 2.518300e+04 |  81.01%| unknown
#   0.6s|     1 |     0 |  8237 |     - |    45M |   0 |4020 |4220 |4223 |   3 |  3 |   0 |   0 | 1.391756e+04 | 2.518300e+04 |  80.94%| unknown
#   0.7s|     1 |     0 |  8385 |     - |    46M |   0 |4020 |4220 |4224 |   4 |  4 |   0 |   0 | 1.391944e+04 | 2.518300e+04 |  80.92%| unknown
#   0.7s|     1 |     0 |  8538 |     - |    47M |   0 |4020 |4220 |4225 |   5 |  5 |   0 |   0 | 1.392366e+04 | 2.518300e+04 |  80.86%| unknown
#   0.7s|     1 |     0 |  8688 |     - |    47M |   0 |4020 |4220 |4226 |   6 |  6 |   0 |   0 | 1.392590e+04 | 2.518300e+04 |  80.84%| unknown
#   0.7s|     1 |     0 |  9010 |     - |    49M |   0 |4020 |4220 |4227 |   7 |  7 |   0 |   0 | 1.393220e+04 | 2.518300e+04 |  80.75%| unknown
#   0.8s|     1 |     0 |  9123 |     - |    50M |   0 |4020 |4220 |4228 |   8 |  8 |   0 |   0 | 1.393759e+04 | 2.518300e+04 |  80.68%| unknown
#   0.8s|     1 |     0 |  9220 |     - |    51M |   0 |4020 |4220 |4229 |   9 |  9 |   0 |   0 | 1.393941e+04 | 2.518300e+04 |  80.66%| unknown
#   0.8s|     1 |     0 |  9861 |     - |    52M |   0 |4020 |4220 |4230 |  10 | 10 |   0 |   0 | 1.394180e+04 | 2.518300e+04 |  80.63%| unknown
#   0.9s|     1 |     0 |  9909 |     - |    53M |   0 |4020 |4220 |4231 |  11 | 12 |   0 |   0 | 1.394207e+04 | 2.518300e+04 |  80.63%| unknown
# r 0.9s|     1 |     0 | 10493 |     - |intshift|   0 |4020 |4220 |4231 |  11 | 14 |   0 |   0 | 1.394207e+04 | 2.147200e+04 |  54.01%| unknown
#   0.9s|     1 |     0 | 10493 |     - |    53M |   0 |4020 |4220 |4231 |  11 | 14 |   0 |   0 | 1.394207e+04 | 2.147200e+04 |  54.01%| unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#   2.1s|     1 |     2 | 10493 |     - |    55M |   0 |4020 |4220 |4231 |  11 | 16 |   0 |  19 | 1.407597e+04 | 2.147200e+04 |  52.54%| unknown
# * 3.5s|     7 |     6 | 13974 | 710.8 |strongbr|   6 |4020 |4220 |4231 |  11 |  1 |   0 |  43 | 1.412877e+04 | 2.081400e+04 |  47.32%| unknown
# * 3.5s|     8 |     7 | 14207 | 642.6 |strongbr|   7 |4020 |4220 |4231 |  11 |  1 |   0 |  44 | 1.412877e+04 | 2.040450e+04 |  44.42%| unknown
# * 3.6s|     9 |     8 | 14366 | 582.1 |strongbr|   8 |4020 |4220 |4231 |  11 |  1 |   0 |  45 | 1.412877e+04 | 2.033900e+04 |  43.95%| unknown
# * 3.6s|    10 |     9 | 14461 | 528.0 |strongbr|   9 |4020 |4220 |4231 |  11 |  1 |   0 |  46 | 1.412877e+04 | 2.030500e+04 |  43.71%| unknown
# r 3.6s|    11 |    10 | 14606 | 489.7 |shifting|  10 |4020 |4220 |4231 |  11 |  0 |   0 |  47 | 1.412877e+04 | 1.978380e+04 |  40.02%| unknown
# r 3.6s|    11 |    10 | 14614 | 490.5 |shifting|  10 |4020 |4220 |4232 |  12 |  1 |   0 |  47 | 1.412877e+04 | 1.975033e+04 |  39.79%| unknown
# r 3.6s|    11 |    10 | 14626 | 491.7 |shifting|  10 |4020 |4220 |4234 |  14 |  3 |   0 |  47 | 1.412877e+04 | 1.948412e+04 |  37.90%| unknown
# * 3.6s|    12 |    11 | 14858 | 468.1 |strongbr|  11 |4020 |4220 |4236 |  16 |  1 |   0 |  48 | 1.412877e+04 | 1.909050e+04 |  35.12%| unknown
# * 3.7s|    13 |    12 | 14952 | 436.9 |strongbr|  12 |4020 |4220 |4236 |  16 |  1 |   0 |  49 | 1.412877e+04 | 1.727800e+04 |  22.29%| unknown
# * 3.7s|    13 |    12 | 14952 | 436.9 |strongbr|  12 |4020 |4220 |4236 |  16 |  1 |   0 |  50 | 1.412877e+04 | 1.716700e+04 |  21.50%| unknown
# * 3.7s|    15 |    12 | 15078 | 383.5 |strongbr|  13 |4020 |4220 |4236 |  16 |  2 |   0 |  56 | 1.412877e+04 | 1.716400e+04 |  21.48%| unknown
# * 5.1s|    25 |    19 | 18789 | 378.3 |strongbr|  13 |4020 |4220 |4235 |  20 |  5 |   0 |  88 | 1.431143e+04 | 1.658276e+04 |  15.87%| unknown
# * 5.5s|    39 |    31 | 22086 | 325.7 |strongbr|  13 |4020 |4220 |4233 |  22 |  1 |   0 |  95 | 1.432478e+04 | 1.635300e+04 |  14.16%| unknown
# * 5.9s|    59 |    24 | 27869 | 313.1 |    LP  |  13 |4020 |4220 |4231 |  28 |  1 |   0 |  98 | 1.432714e+04 | 1.512900e+04 |   5.60%|   3.80%
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# * 6.0s|    67 |    19 | 28701 | 287.8 |    LP  |  13 |4020 |4220 |4231 |  28 |  1 |   0 |  98 | 1.440700e+04 | 1.492800e+04 |   3.62%|  10.65%
# * 6.1s|    78 |    16 | 30159 | 265.6 |    LP  |  13 |4020 |4220 |4231 |  28 |  1 |   0 |  99 | 1.440700e+04 | 1.480400e+04 |   2.76%|  17.56%
# * 6.2s|    90 |    12 | 32550 | 256.6 |    LP  |  13 |4020 |4220 |4231 |  28 |  2 |   0 |  99 | 1.444881e+04 | 1.478500e+04 |   2.33%|  42.00%
#   6.3s|   100 |    10 | 34309 | 248.5 |    65M |  13 |4020 |4220 |4231 |  28 |  0 |   0 |  99 | 1.444881e+04 | 1.478500e+04 |   2.33%|  56.28%
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 6.45
# Solving Nodes      : 118
# Primal Bound       : +1.47850000000000e+04 (225 solutions)
# Dual Bound         : +1.47850000000000e+04
# Gap                : 0.00 %

# %%
x,y = model.data
edges = [(i,j) for (i,j) in x if model.getVal(x[i,j]) > EPS]
warehouses = [j for j in y if model.getVal(y[j]) > EPS]

# %%
print("Optimal value=", model.getObjVal())
print("Warehouse at nodes:", warehouses)
print("Edges:", edges)
# Out:
# Optimal value= 14785.0
# Warehouse at nodes: [1, 4, 8, 17, 18, 20]
# Edges: [(7, 1), (22, 1), (32, 1), (43, 1), (44, 1), (50, 1), (79, 1), (82, 1), (87, 1), (89, 1), (90, 1), (107, 1), (110, 1), (111, 1), (121, 1), (124, 1), (131, 1), (139, 1), (152, 1), (157, 1), (166, 1), (168, 1), (171, 1), (176, 1), (179, 1), (182, 1), (190, 1), (191, 1), (193, 1), (198, 1), (3, 4), (24, 4), (26, 4), (33, 4), (36, 4), (37, 4), (46, 4), (61, 4), (68, 4), (69, 4), (83, 4), (88, 4), (91, 4), (97, 4), (101, 4), (104, 4), (106, 4), (109, 4), (116, 4), (117, 4), (118, 4), (119, 4), (120, 4), (153, 4), (155, 4), (159, 4), (162, 4), (165, 4), (167, 4), (175, 4), (178, 4), (184, 4), (188, 4), (200, 4), (6, 8), (11, 8), (12, 8), (15, 8), (21, 8), (27, 8), (29, 8), (30, 8), (31, 8), (34, 8), (40, 8), (42, 8), (47, 8), (49, 8), (52, 8), (57, 8), (72, 8), (78, 8), (93, 8), (95, 8), (96, 8), (102, 8), (105, 8), (113, 8), (114, 8), (122, 8), (135, 8), (137, 8), (146, 8), (161, 8), (163, 8), (169, 8), (177, 8), (180, 8), (187, 8), (197, 8), (5, 17), (9, 17), (13, 17), (17, 17), (20, 17), (23, 17), (54, 17), (56, 17), (60, 17), (62, 17), (75, 17), (77, 17), (80, 17), (81, 17), (84, 17), (103, 17), (115, 17), (123, 17), (127, 17), (129, 17), (132, 17), (133, 17), (136, 17), (138, 17), (141, 17), (147, 17), (154, 17), (160, 17), (164, 17), (172, 17), (183, 17), (185, 17), (186, 17), (1, 18), (4, 18), (10, 18), (14, 18), (16, 18), (19, 18), (25, 18), (28, 18), (35, 18), (39, 18), (45, 18), (51, 18), (53, 18), (59, 18), (64, 18), (65, 18), (66, 18), (74, 18), (85, 18), (86, 18), (92, 18), (94, 18), (98, 18), (112, 18), (125, 18), (126, 18), (130, 18), (134, 18), (140, 18), (144, 18), (145, 18), (149, 18), (156, 18), (158, 18), (174, 18), (181, 18), (192, 18), (194, 18), (195, 18), (196, 18), (2, 20), (8, 20), (18, 20), (38, 20), (41, 20), (48, 20), (55, 20), (58, 20), (63, 20), (67, 20), (70, 20), (71, 20), (73, 20), (76, 20), (99, 20), (100, 20), (108, 20), (128, 20), (142, 20), (143, 20), (148, 20), (150, 20), (151, 20), (170, 20), (173, 20), (189, 20), (199, 20)]

# %% [markdown]
# ## 4. Visualize the path in map

# %% [markdown]
# There would be multiple result for the optimal route. However, we will take the first 10 route to visualize in map

# %%
G = ox.graph_from_address( place_name, network_type='drive' )
# Out:
# /Users/thuannt.se/miniconda3/envs/ox/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /Users/thuannt.se/miniconda3/envs/ox/lib/python3.11/site-packages/shapely/set_operations.py:340: RuntimeWarning: invalid value encountered in union
#   return lib.union(a, b, **kwargs)
# /Users/thuannt.se/miniconda3/envs/ox/lib/python3.11/site-packages/shapely/set_operations.py:340: RuntimeWarning: invalid value encountered in union
#   return lib.union(a, b, **kwargs)

# %%
selective_edges = edges[:10]

# %%
def create_wh_shop_pair(edges, warehouse_data, shop_data):
    result = []
    for edge in edges:
        shop = list(filter(lambda data: data.id == edge[0], shop_data))[0]
        warehouse = list(filter(lambda data: data.id == edge[1], warehouse_data))[0]
        result.append((shop, warehouse))
    return result

# %%
pair_nodes = create_wh_shop_pair(selective_edges, warehouse_data, shop_data)

# %%
def plot_route(G, pair_nodes, m):
    for node in pair_nodes:
        org = ox.distance.nearest_nodes(G, node[1].long, node[1].lat)
        dst = ox.distance.nearest_nodes(G, node[0].long, node[0].lat)
        route1 = ox.shortest_path(G, org, dst, weight='travel_time')
        if (None!=route1):
            route_map = ox.plot_route_folium(G, route1, route_map=m, route_color='#ff0000', opacity=0.5)

# %%
plot_route(G, pair_nodes, place_map)
# Out:
# [(<Shop.Shop object at 0x17cd22590>, <Warehouse.Warehouse object at 0x112295090>), (<Shop.Shop object at 0x17cd22090>, <Warehouse.Warehouse object at 0x112295090>), (<Shop.Shop object at 0x17cd21bd0>, <Warehouse.Warehouse object at 0x112295090>), (<Shop.Shop object at 0x17cd21810>, <Warehouse.Warehouse object at 0x112295090>), (<Shop.Shop object at 0x17cd21750>, <Warehouse.Warehouse object at 0x112295090>), (<Shop.Shop object at 0x17cd21510>, <Warehouse.Warehouse object at 0x112295090>), (<Shop.Shop object at 0x17cd208d0>, <Warehouse.Warehouse object at 0x112295090>), (<Shop.Shop object at 0x17cd20790>, <Warehouse.Warehouse object at 0x112295090>), (<Shop.Shop object at 0x17cd205d0>, <Warehouse.Warehouse object at 0x112295090>), (<Shop.Shop object at 0x17cd20490>, <Warehouse.Warehouse object at 0x112295090>)]

# %%
place_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c07014c50b4cec261921ceecd3743b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c07014c50b4cec261921ceecd3743b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c07014c50b4cec261921ceecd3743b2 = L.map(
#                 &quot;map_6c07014c50b4cec261921ceecd3743b2&quot;,
#                 {
#                     center: [10.7757, 106.7004],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_337e90fcb13c8c28c35398b60716c6ba = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c07014c50b4cec261921ceecd3743b2);
#
#
#             var marker_cluster_82b15471ac6a9c359f6eb4c9b91c5bff = L.markerClusterGroup(
#                 {}
#             );
#             map_6c07014c50b4cec261921ceecd3743b2.addLayer(marker_cluster_82b15471ac6a9c359f6eb4c9b91c5bff);
#
#
#             var marker_6bc9d098d97ba293cf60a5b10505a72b = L.marker(
#                 [10.7702895, 106.6927854],
#                 {}
#             ).addTo(marker_cluster_82b15471ac6a9c359f6eb4c9b91c5bff);
#
#
#             var icon_8bbdb68440a919adeeebba1615585fcf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shop&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6bc9d098d97ba293cf60a5b10505a72b.setIcon(icon_8bbdb68440a919adeeebba1615585fcf);
#
#
#         var popup_6f52819adfccf36e218b265a01b88931 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3c52c5700ff2d47757df32d2ff0e89a = $(`&lt;div id=&quot;html_f3c52c5700ff2d47757df32d2ff0e89a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;shop&lt;/div&gt;`)[0];
#                 popup_6f52819adfccf36e218b265a01b88931.setContent(html_f3c52c5700ff2d47757df32d2ff0e89a);
#
#
#
#         marker_6bc9d098d97ba293cf60a5b10505a72b.bindPopup(popup_6f52819adfccf36e218b265a01b88931)
#         ;
#
#
#
#
#             var marker_86bb57f3948cd1b1ff21cda30b63bbb9 = L.marker(
#                 [10.7817145, 106.6982688],
#                 {}
#             ).addTo(marker_cluster_82b15471ac6a9c359f6eb4c9b91c5bff);
#
#
#             var icon_555c82eedd3480f41f97ce737fd043c9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shop&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_86bb57f3948cd1b1ff21cda30b63bbb9.setIcon(icon_555c82eedd3480f41f97ce737fd043c9);
#
#
#         var popup_2c50588b165b9f3e6ab7d9e283489b28 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e71cf483a9ef661312dfdcb9ee023db1 = $(`&lt;div id=&quot;html_e71cf483a9ef661312dfdcb9ee023db1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;shop&lt;/div&gt;`)[0];
#                 popup_2c50588b165b9f3e6ab7d9e283489b28.setContent(html_e71cf483a9ef661312dfdcb9ee023db1);
#
#
#
#         marker_86bb57f3948cd1b1ff21cda30b63bbb9.bindPopup(popup_2c50588b165b9f3e6ab7d9e283489b28)
#         ;
#
#
#
#
#             var marker_9133a4f08c032004f7895e4ada9ab985 = L.marker(
#                 [10.7685768, 106.6948596],
#                 {}
#             ).addTo(marker_cluster_82b15471ac6a9c359f6eb4c9b91c5bff);
#
#
#             var icon_99092692e70bd6f74ae5fdad87ac9a0f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shop&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9133a4f08c032004f7895e4ada9ab985.setIcon(icon_99092692e70bd6f74ae5fdad87ac9a0f);
#
#
#         var popup_9c1520a1b37a8a9f936811215301af15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
